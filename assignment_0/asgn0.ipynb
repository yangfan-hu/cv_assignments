# %% [markdown]
# # Assignmen0 图像的基本操作与变换
#
# ### 实验目的
# 1. 掌握OpenCV的基本图像读写操作
# 2. 理解图像的颜色空间及其转换
# 3. 理解图像的几何变换
# 4. 通过手动实现部分算法加深对图像处理的理解

# %% [markdown]
# #### 任务1：图像的基本读写与显示（使用OpenCV）
#
#
# 1. 读取一张彩色图像（`lena.png`）
# 2. 显示原图像，并等待按键关闭窗口
# 3. 将原图像保存为`lena.jpg`（注意保存格式）
# 4. 输出图像的形状、大小、数据类型等基本信息

# %%
import cv2
import numpy as np

### YOUR CODE HERE


# 1. read image


# 2. display image


# 3. save iamge



### YOUR CODE END

# 4. 输出图像信息
print(f"图像形状: {img.shape}")
print(f"图像大小: {img.size}")
print(f"数据类型: {img.dtype}")
# Out:
# 图像形状: (512, 512, 3)
# 图像大小: 786432
# 数据类型: uint8

# %% [markdown]
# #### 任务2：颜色空间变换（调用OpenCV函数）
#
# **要求：**
# 1. 将原图像转换为以下颜色空间并显示（使用`cv2.imshow`）：
#    - HSV（色相、饱和度、明度）
#    - Lab（明度和色彩对立维度）
#    - YCrCb（亮度、红色差、蓝色差）
# 2. 保存转换后的图像为`hsv.jpg`、`lab.jpg`、`ycr.jpg`
# 3. 从HSV空间中提取并显示H、S、V三个通道（使用3个窗口分别显示） split函数
# 4. 手动实现图片的灰度化
#
# **原理说明：**
# - **HSV颜色空间**：将颜色分解为色调(H)、饱和度(S)和明度(V)，更符合人类描述颜色的方式
# - **Lab颜色空间**：感知均匀的颜色空间，L分量表示亮度，a和b表示颜色对立维度
# - **YCrCb颜色空间**：常用于图像压缩，Y表示亮度，Cr和Cb表示色差

# %%
# 1. HSB
### YOUR CODE HERE

### YOUR CODE END
cv2.imshow('HSV Image', hsv_img)

# 2. Lab
### YOUR CODE HERE

### YOUR CODE END
cv2.imshow('Lab Image', lab_img)

# 3. YCrCb
### YOUR CODE HERE

### YOUR CODE END
cv2.imshow('YCrCb Image', ycr_img)

# 4. Split HSV
### YOUR CODE HERE

### YOUR CODE END

# show channels
cv2.imshow('Hue Channel (H)', h)
cv2.imshow('Saturation Channel (S)', s)
cv2.imshow('Value Channel (V)', v)



# pause window
cv2.waitKey(0)
cv2.destroyAllWindows()



# print channel information
print(f"HSV图像形状: {hsv_img.shape}")
print(f"H通道范围: [{np.min(h)}， {np.max(h)}]")
print(f"S通道范围: [{np.min(s)}， {np.max(s)}]")
print(f"V通道范围: [{np.min(v)}， {np.max(v)}]")
# Out:
# HSV图像形状: (512, 512, 3)
# H通道范围: [0， 179]
# S通道范围: [5， 246]
# V通道范围: [59， 255]

# %% [markdown]
# ### 任务3 手动实现灰度化（不使用cvtColor）
#
# **要求：**
# 1. 根据加权平均法公式实现灰度化：`Gray = 0.299 * R + 0.587 * G + 0.114 * B`
# 2. 注意OpenCV中颜色通道的顺序为BGR
# 3. 通过numpy矩阵操作实现图片灰度化
#
# **原理说明：**
#
# 灰度化是将彩色图像转换为灰度图像的过程，常用的方法有：
#
# | 方法 | 公式 | 特点 |
# |------|------|------|
# | 加权平均法 | Gray = 0.299R + 0.587G + 0.114B | 符合人眼灵敏度，最常用 |
# | 平均值法 | Gray = (R + G + B) / 3 | 简单但效果较差 |
# | 最大值法 | Gray = max(R, G, B) | 亮度偏高 |
# | 最小值法 | Gray = min(R, G, B) | 亮度偏低 |
#
# 本实验要求使用**加权平均法**手动实现。

# %%
def convert_to_gray_scale(bgr_image):
    ### YOUR CODE HERE


    ### YOUR CODE END
    return gray_image

img_gray = convert_to_gray_scale(img)

img_gray_ref = np.load('./references/lena_gray.npy')

cv2.imshow('gray_manual', img_gray.astype(np.uint8))
cv2.waitKey(0)
cv2.destroyAllWindows()

if not np.allclose(img_gray, img_gray_ref):
    print('Incorrect values! Please check your implementation.')

# %% [markdown]
# ### 图像左右翻转实验说明（不使用cv2.flip）
#
#
# **要求：**
# - 掌握图像左右翻转的基本原理和实现方法
# - 理解图像坐标变换的数学原理
# - 通过numpy矩阵操作，不调用opencv实现图片的水平翻转(horizontal flip)加深对图像几何变换的理解
#
# **原理**
# 图像左右翻转的实质是将图像中的每个像素点沿垂直中轴线进行镜像对称变换。对于尺寸为 $H \times W$ 的图像，其坐标变换公式为：
#
# - **原始坐标**：$(x, y)$，其中 $x$ 为水平坐标(0 ≤ x < W)，$y$ 为垂直坐标(0 ≤ y < H)
# - **变换后坐标**：$(x', y') = (W - 1 - x, y)$
#
# 对应的变换矩阵为：
# $$M = \begin{bmatrix} -1 & 0 & W-1 \\ 0 & 1 & 0 \end{bmatrix}$$

# %%
def flip_image_horizontal(image):
    ### YOUR CODE HERE

    ### YOUR CODE END
    
    return flipped_image

img_flip = flip_image_horizontal(img)


cv2.imshow('flipped_manual', img_flip)
cv2.waitKey(0)
cv2.destroyAllWindows()

img_flip_ref = np.load('./references/lena_flip.npy')
if not np.allclose(img_flip, img_flip_ref):
    print('Incorrect values! Please check your implementation.')
